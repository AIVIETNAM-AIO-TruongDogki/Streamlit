# %%
from statistic import Statistic

# %%
sample_data = Statistic("data/student_dataset_300.xlsx")
sample_data.data
# Out:
#      Student_ID             Name  Gender  Age  Grade_Level  Math  English  \
# 0             1  Nguyen Thao Han    Male   16           10    58       97
# 1             2      Tran Ha Hai    Male   15           12    62       95
# 2             3   Dang Khang Han    Male   16           10    98       71
# 3             4    Tran Yen Long  Female   15           12    68       90
# 4             5    Tran Viet Hai  Female   15           11    67       79
# ..          ...              ...     ...  ...          ...   ...      ...
# 295         296   Huynh Trang Ha  Female   16           11    51       64
# 296         297   Nguyen Long Vy  Female   17           12    89       53
# 297         298    Bui Long Dung  Female   17           11    94       59
# 298         299      Le Mai Tung  Female   15           12    96       89
# 299         300     Vo Tung Ngan    Male   16           11    95       76
#
#      Reading  Science  History  Attendance_%  Study_Hours_Per_Week  \
# ...

# %%
sample_data.process_query("Show me the highest math score")
# Out:
#     Student_ID          Name Gender  Age  Grade_Level  Math  English  Reading  \
# 91          92  Bui Ngan Hai   Male   15           12   100       92       83
#
#     Science  History  Attendance_%  Study_Hours_Per_Week Extracurricular  \
# 91       69       79          91.1                     1             Yes
#
#    Parent_Education   GPA
# 91           Master  8.46
